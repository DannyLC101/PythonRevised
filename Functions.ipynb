# %%
a =5
def add1(a):
    b=a+1
    return b
add1(a)
# Out:
# 6

# %%
def add1(a):
    b=a+1
    pass
add1(5)

# %%
list = [1,2,3,4,5]
def printstuff(stuff):
    for i,s in enumerate(stuff):
        print("Index", i , "Value is ",s)
printstuff(list)
# Out:
# Index 0 Value is  1
# Index 1 Value is  2
# Index 2 Value is  3
# Index 3 Value is  4
# Index 4 Value is  5

# %%
Artist = ("MJ", "JJ", "PF")
def artname(*names):
    for n in names:
        print(n)
artname(Artist)
# Out:
# ('MJ', 'JJ', 'PF')

# %%
a=1
def add(b):
    return a+b
c=add(10)
print(c)
# Out:
# 11

# %%
#this is invalid function
def f(*x):
    return sum(c)
